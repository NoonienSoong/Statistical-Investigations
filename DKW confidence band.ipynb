# %%
# %pylab inline
import scipy.stats as stats
import numpy as np
import statsmodels.api as sm
rcParams['figure.figsize'] = 10,8
rcParams['axes.grid'] = True
rcParams['axes.facecolor'] = 'f5f5f5'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **This notebook follows from the problem:**
# > Generate 100 observations from a N(0, 1) distribution. Compute a 95 percent confidence band for the CDF F. Repeat this 1000 times to see how often the confidence band contains the true distribution function. Repeat using data generated from a Cauchy distribution.
#
# _**where,**_
#
# _$$\epsilon = \frac{1}{2n}\ln(\frac{2}{\alpha})$$_
#
# derived from the DKW inequality

# %%
inside = 0
outside = 0
alpha = 0.05
e = np.sqrt(np.log(2./alpha) / (2 * 100))
for i in range(1000):
 sample = np.random.normal(0,1,100)   
 ecdf = sm.distributions.empirical_distribution.ECDF(sample)
 x = np.linspace(min(sample),max(sample))
 y = stats.norm.cdf(x)
 y1 = ecdf(x)
 u_band = greater_equal(y1+e,y)
 l_band = greater_equal(y,y1-e)
 if u_band.all() and l_band.all():
  inside +=1
 else:
  outside +=1
  
print float(inside)/float(inside + outside)
# Out:
# 0.971

# %%
plot(x,y,'m')
plot(x,y1-e,'b--')
plot(x,y1+e,'r--')
legend(['True CDF','Lower band','Upper band'])
