# %%
# %pylab inline
__author__ = 'Nicholas Jackson'
__date__ = ''
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pygeocoder as geo
from decimal import *

plt.rcParams['figure.figsize'] = 11,10
plt.rcParams['axes.grid'] = True
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def mean_plot(size):
    data = []
    data1 = []
    means = []
    means1 = []
    for i in range(size):
        x = np.random.normal(0,1)
        data.append(x)
        m = sum(data)/len(data)
        means.append(m)
    for i in range(size):
        x1 = np.random.standard_cauchy()
        data1.append(x1)
        m1 = sum(data1)/len(data1)
        means1.append(m1)
    plt.plot(means)
    plt.plot(means1)
    plt.ylabel('$Sample$ $Means$',size=40)
    plt.xlabel('$n$',size=50)

# %% [markdown]
# The Cauchy Distrobution does not have a converging mean. Shown in the graph below

# %%
mean_plot(10000)

# %%
df = pd.read_csv('201412-citibike-tripdata.csv')
df
# Out:
#     tripduration           starttime            stoptime  start station id  \
# 0           1257  12/1/2014 00:00:28  12/1/2014 00:21:25               475
# 1            275  12/1/2014 00:00:43  12/1/2014 00:05:18               498
# 2            450  12/1/2014 00:01:22  12/1/2014 00:08:52               444
# 3           1126  12/1/2014 00:02:17  12/1/2014 00:21:03               475
# 4            331  12/1/2014 00:02:21  12/1/2014 00:07:52               519
# 5            162  12/1/2014 00:02:37  12/1/2014 00:05:19               229
# 6            155  12/1/2014 00:02:43  12/1/2014 00:05:18               229
# 7            493  12/1/2014 00:03:12  12/1/2014 00:11:25               305
# 8            521  12/1/2014 00:03:16  12/1/2014 00:11:57                82
# 9            349  12/1/2014 00:03:37  12/1/2014 00:09:26               470
# 10          8761  12/1/2014 00:04:48  12/1/2014 02:30:49               295
# 11           428  12/1/2014 00:05:27  12/1/2014 00:12:35               465
# 12          1102  12/1/2014 00:05:33  12/1/2014 00:23:55               369
# 13           336  12/1/2014 00:05:50  12/1/2014 00:11:26               386
# 14          1051  12/1/2014 00:06:18  12/1/2014 00:23:49               369
# 15           354  12/1/2014 00:06:23  12/1/2014 00:12:17               487
# 16           670  12/1/2014 00:07:04  12/1/2014 00:18:14               536
# 17           420  12/1/2014 00:07:04  12/1/2014 00:14:04               300
# 18          2284  12/1/2014 00:07:14  12/1/2014 00:45:18               448
# 19           509  12/1/2014 00:07:26  12/1/2014 00:15:55               237
# 20           440  12/1/2014 00:07:48  12/1/2014 00:15:08               515
# 21          8558  12/1/2014 00:08:06  12/1/2014 02:30:44               295
# 22           807  12/1/2014 00:08:26  12/1/2014 00:21:53               369
# 23          1054  12/1/2014 00:09:18  12/1/2014 00:26:52               501
# 24           203  12/1/2014 00:09:27  12/1/2014 00:12:50               161
# 25           442  12/1/2014 00:10:01  12/1/2014 00:17:23               444
# 26          1189  12/1/2014 00:10:06  12/1/2014 00:29:55               459
# 27           197  12/1/2014 00:10:12  12/1/2014 00:13:29               364
# 28          1170  12/1/2014 00:10:23  12/1/2014 00:29:53               459
# 29           267  12/1/2014 00:10:29  12/1/2014 00:14:56               505
# 30           404  12/1/2014 00:11:01  12/1/2014 00:17:45               523
# 31          2836  12/1/2014 00:11:04  12/1/2014 00:58:20               532
# 32          1068  12/1/2014 00:12:10  12/1/2014 00:29:58               459
# 33           208  12/1/2014 00:12:17  12/1/2014 00:15:45               476
# 38               -73.960241             313     Washington Ave & Park Ave
# 39               -74.007114             347      W Houston St & Hudson St
# 40               -73.997236             442               W 27 St & 7 Ave
# 41               -73.999744             330           Reade St & Broadway
# 42               -73.989111             393             E 5 St & Avenue C
# 43               -73.994156             488               W 39 St & 9 Ave
# 44               -73.992939             412         Forsyth St & Canal St
# 45               -73.991255             236           St Marks Pl & 2 Ave
# 46               -74.001547             146          Hudson St & Reade St
# 47               -74.007114             489              10 Ave & W 28 St
# 48               -73.986724             361          Allen St & Hester St
# 49               -73.978058             323   Lawrence St & Willoughby St
# 50               -74.000040             476               E 31 St & 3 Ave
# 51               -73.997236             457            Broadway & W 58 St
# 52               -73.983169             478              11 Ave & W 41 St
# 53               -74.001547             337           Old Slip & Front St
# 54               -73.995721             164               E 47 St & 2 Ave
# 55               -74.002150             391           Clark St & Henry St
# 56               -73.971879             448              W 37 St & 10 Ave
# 57               -73.979661             150             E 2 St & Avenue C
# 58               -74.005524             264          Maiden Ln & Pearl St
# 59               -73.987882             265      Stanton St & Chrystie St
#                         ...             ...                           ...
#
#     end station latitude  end station longitude  bikeid    usertype  \
# 0              40.750450             -73.994811   16047    Customer
# 1              40.744449             -73.983035   18472  Subscriber
# 2              40.743174             -74.003664   19589  Subscriber
# 3              40.750450             -73.994811   21142    Customer
# 4              40.744023             -73.976056   18679  Subscriber
# 5              40.730477             -73.999061   21668  Subscriber
# 6              40.730477             -73.999061   16205  Subscriber
# 7              40.748238             -73.978311   18234  Subscriber
# 8              40.705693             -74.016777   17045  Subscriber
# 9              40.740964             -73.986022   18805  Subscriber
# 10             40.715816             -73.994224   21397    Customer
# 11             40.763707             -73.985162   21249  Subscriber
# 12             40.763406             -73.977225   17785  Subscriber
# 13             40.715422             -74.011220   21392  Subscriber
# 14             40.763406             -73.977225   16102  Subscriber
# 15             40.724537             -73.981854   21447  Subscriber
# 16             40.750073             -73.998393   15871  Subscriber
# 17             40.724561             -73.995653   16470  Subscriber
# 18             40.760875             -74.002777   17698  Subscriber
# 19             40.720828             -73.977932   15404  Subscriber
# 20             40.766953             -73.981693   19178  Subscriber
# 21             40.715816             -73.994224   16206    Customer
# 22             40.756405             -73.990026   19050  Subscriber
# 23             40.726281             -73.989780   19929  Subscriber
# 24             40.730287             -73.990765   19682  Subscriber
# 25             40.742388             -73.997262   21349  Subscriber
# 26             40.722055             -73.989111   16069  Subscriber
# 27             40.693631             -73.962236   20362  Subscriber
# 28             40.722055             -73.989111   15001    Customer
# 29             40.750073             -73.998393   19041  Subscriber
# 30             40.763707             -73.985162   15724  Subscriber
# 31             40.732264             -73.998522   18165  Subscriber
# 32             40.722055             -73.989111   19667    Customer
# 33             40.747659             -73.984907   18496  Subscriber
# 34             40.693261             -73.968896   17552  Subscriber
# 35             40.722055             -73.989111   18641    Customer
# 36             40.729554             -73.980572   18938  Subscriber
# 37             40.747348             -73.997236   18155  Subscriber
# 38             40.696102             -73.967510   18090  Subscriber
# 39             40.728739             -74.007488   19678  Subscriber
# 40             40.746647             -73.993915   19525    Customer
# 41             40.714505             -74.005628   19646  Subscriber
# 42             40.722992             -73.979955   16227  Subscriber
# 43             40.756458             -73.993722   15027  Subscriber
# 44             40.715816             -73.994224   17483    Customer
# 45             40.728419             -73.987140   19947  Subscriber
# 46             40.716250             -74.009106   18174  Subscriber
# 47             40.750664             -74.001768   18186  Subscriber
# 48             40.716059             -73.991908   15302  Subscriber
# 49             40.692362             -73.986317   17203  Subscriber
# 50             40.743943             -73.979661   16232  Subscriber
# 51             40.766953             -73.981693   15271  Subscriber
# 52             40.760301             -73.998842   15471  Subscriber
# 53             40.703799             -74.008387   15474  Subscriber
# 54             40.753231             -73.970325   21332  Subscriber
# 55             40.697601             -73.993446   17014  Subscriber
# 56             40.756604             -73.997901   20062  Subscriber
# 57             40.720874             -73.980858   19423  Subscriber
# 58             40.707065             -74.007319   18175  Subscriber
# 59             40.722293             -73.991475   20841  Subscriber
#                      ...                    ...     ...         ...
#
#     birth year  gender
# 0          NaN       0
# 1         1988       2
# 2         1983       1
# 3          NaN       0
# 4         1986       2
# 5         1973       1
# 6         1986       1
# 7         1990       1
# 8         1982       1
# 9         1983       1
# 10         NaN       0
# 11        1983       1
# 12        1981       1
# 13        1970       1
# 14        1983       1
# 15        1983       1
# 16        1979       1
# 17        1991       2
# 18        1989       2
# 19        1991       1
# 20        1981       1
# 21         NaN       0
# 22        1968       1
# 23        1953       2
# 24        1993       1
# 25        1964       1
# 26        1988       1
# 27        1987       1
# 28         NaN       0
# 29        1986       1
# 30        1966       1
# 31        1973       2
# 32         NaN       0
# 33        1957       1
# 34        1984       1
# 35         NaN       0
# 36        1987       1
# 37        1976       1
# 38        1986       1
# 39        1963       1
# 40         NaN       0
# 41        1977       1
# 42        1978       1
# 43        1967       1
# 44         NaN       0
# 45        1974       1
# 46        1969       1
# 47        1977       1
# 48        1986       1
# 49        1976       1
# 50        1980       1
# 51        1988       1
# 52        1958       1
# 53        1986       1
# 54        1988       1
# 55        1973       2
# 56        1982       1
# 57        1990       1
# 58        1989       1
# 59        1974       1
#            ...     ...
#
# [399069 rows x 15 columns]

# %% [markdown]
# ## plotting histogram Customers vs Time (mins) ##
# ####Note: in order to find 99% of the data we take into consideration the following proportion:
# $$\frac{3}{99.7}=\frac{x}{99}$$
#
# $$ x = 2.97$$

# %%
Mu = df['tripduration'].mean()
sigma = df['tripduration'].std()
x = 2.97*sigma + Mu

data_tail = df[df['tripduration']< x]['tripduration'].tolist()
time_mins = []
for i in data_tail:
    time_mins.append(i/60)
plt.hist(time_mins,bins=50)
# Out:
# (array([41531, 99311, 88316, 58223, 36357, 22856, 15339, 10813,  7577,
#          3618,  4020,  2764,  1828,  1330,   871,   544,   422,   322,
#           257,   136,   199,   150,   144,   121,   111,   113,    95,
#            83,    60,    47,    61,    58,    61,    41,    61,    47,
#            35,    31,    32,    11,    33,    28,    33,    23,    30,
#            16,    22,    19,    22,    26]),
#  array([   1. ,    3.9,    6.8,    9.7,   12.6,   15.5,   18.4,   21.3,
#           24.2,   27.1,   30. ,   32.9,   35.8,   38.7,   41.6,   44.5,
#           47.4,   50.3,   53.2,   56.1,   59. ,   61.9,   64.8,   67.7,
#           70.6,   73.5,   76.4,   79.3,   82.2,   85.1,   88. ,   90.9,
#           93.8,   96.7,   99.6,  102.5,  105.4,  108.3,  111.2,  114.1,
#          117. ,  119.9,  122.8,  125.7,  128.6,  131.5,  134.4,  137.3,
#          140.2,  143.1,  146. ]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# ***Most used bike***  (i.e. The Bike that was rented the most)

# %%
def most_common(list):
    return max(set(list),key=list.count)

most_common(df['bikeid'].tolist())
#17346

# %% [markdown]
# ***Percent of Female Customers***

# %%
females = len(df[df['gender'] == 2 ]['gender'].tolist())
total_gender = len(df['gender'].tolist())
#percent of females

females/Decimal(total_gender)
#19%
# Out:
# Decimal('0.1913879554663479247949602700')

# %% [markdown]
# #** The Probability that a biker ends in Manhattan given they started in Brooklyn**#
# ###A = the biker ends in Manhattan###
# ###B = the biker starts in Brooklyn###
# ##$$P(A|B) = \frac{P(A,B)}{P(B)}$$##
# <img src ='files/citibike-nyc-bike-share-docking-stations-map.jpg'>
#
# #This problem was solved by:#
#
# **1**. Choosing landmarks to divide the city up by (See picture) this allows me to seperate Bk and Manhattan
#
# **2**. Find all bikes that were rented from Bk and brought to Manhattan. Because of the geography I had to
#    find all bikes that started to the right of the "NEast_River" longitude (i.e Williamsburg and parts of southern Bk)
#    and see how many ended in manhattan that had to be done twice since the way the city was divided I first found the
#    bikes that ended in the northern part of manhattan and then the southern. These to numbers were then added togther
#    for the southern part of Bk (or Downtown Bk) the same process was done
#
# **3**. Then I found my reduced sample space which in this case was just all bikes that started in Bk
#
# **4**. At last dividing the finding I came to my result

# %%
NEast_river =geo.Geocoder.geocode('East River Park')
Bk_bridge = geo.Geocoder.geocode('Empire Fulton Ferry')
Rd_hook = geo.Geocoder.geocode('Brooklyn Bridge Park Pier 5')

# %%
#lat     |    long
Bk_bridge.coordinates
# (40.704224, -73.9933767)
NEast_river.coordinates
# (40.7153271, -73.9754516)
Rd_hook.coordinates
# (40.6948689, -74.0017282)
# Out:
# (40.6948689, -74.0017282)

# %% [markdown]
# Everything that starts right of North East river latitutude (i.e. williamsburg and
# parts of southern BK) and ends in manhattan

# %%
North_Bk1 = len(df[df['start station longitude'] > -73.972448][df['start station latitude'] < 40.719995][df['end station longitude'] < -73.972448][df['end station latitude'] > 40.703543])
North_bk2 = len(df[df['start station longitude'] > -73.972448][df['start station latitude'] < 40.719995][df['end station longitude'] < -74.0017282][df['end station latitude'] < 40.703543]) 
North_bk = North_Bk1 + North_bk2

# %% [markdown]
# Everthing that starts in downtown bk and ends in manhattan

# %%
South_bk1 = len(df[df['start station longitude'] < -73.972448][df['start station longitude'] > -74.0017282][df['start station latitude'] < 40.704224][df['end station longitude'] < -73.972448 ][df['end station latitude'] > 40.703543])
South_bk2 = len(df[df['start station longitude'] < -73.972448][df['start station longitude'] > -74.0017282][df['start station latitude'] < 40.704224][df['end station longitude'] < -74.0017282 ][df['end station latitude'] < 40.703543])
South_bk = South_bk1 + South_bk2

# %% [markdown]
# now finding bikes that start in bk

# %%
Start_Nbk = len(df[df['start station longitude'] > -73.972448][df['start station latitude']< 40.719995]) 
Start_Sbk = len(df[df['start station longitude'] < -73.972448][df['start station longitude'] > -74.0017282][df['start station latitude'] < 40.703543])
Start_bk = Start_Nbk + Start_Sbk

# %% [markdown]
# ###The answer:###

# %%
P = (North_bk+South_bk)/Decimal(Start_bk)

# %%
P
# Out:
# Decimal('0.2036197262936270143331443842')
